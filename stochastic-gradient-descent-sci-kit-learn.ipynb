# %%
from sklearn.datasets import load_diabetes
x,y = load_diabetes(return_X_y=True)

# %%
print(x.shape)
print(y.shape)
# Out:
# (442, 10)
# (442,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=10)

#splitting training data and testing data

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (353, 10)
# (89, 10)
# (353,)
# (89,)

# %%
from sklearn.linear_model import SGDRegressor
SGDR = SGDRegressor(learning_rate="constant",max_iter=50,eta0=0.001)

# %%
SGDR.fit(x_train,y_train)
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_stochastic_gradient.py:1548: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# SGDRegressor(eta0=0.001, learning_rate='constant', max_iter=50)

# %%
print("Slope= ",SGDR.coef_)
print("Intercept= ",SGDR.intercept_)
# Out:
# Slope=  [ 12.94545701   2.57921705  34.37777438  26.23512292  12.22744424
#    9.93744955 -25.35610722  26.985734    34.44923877  22.4497101 ]
# Intercept=  [153.13510555]

# %%
y_predict = SGDR.predict(x_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_predict)
# Out:
# 0.09247347473914747
